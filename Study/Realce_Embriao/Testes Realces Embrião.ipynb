# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Importando imagens para teste

# %%
target = './embriaoteste.png'
target2 = './embriaoteste2.png'
target3 = './embriaoteste3.png'
target4 = './embriaoteste4.png'
target5 = './embriaoteste5.png'
target6 = './embriaoteste6.png'
target7 = './embriaoteste7.png'

# %% [markdown]
# # Algoritmo para remoção de fundo

# %%
def kmeans_algorithm(input_image):
    two_dimensional_image = input_image.reshape((-1, 3))
    two_dimensional_image = np.float32(two_dimensional_image)

    criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 10, 1.0)
    clusters = 3
    flags = cv.KMEANS_PP_CENTERS

    result_image_compactness, result_image_labels, result_image_centers = cv.kmeans(two_dimensional_image, clusters, None, criteria, 10, flags)

    result_image_centers = np.uint8(result_image_centers)
    result_image = result_image_centers[result_image_labels.flatten()]
    result_image = result_image.reshape((input_image.shape))

    thresholded_blue_component, thresholded_green_component, thresholded_red_component = cv.split(result_image)

    used_threshold, thresholded_bgr_image = cv.threshold(result_image, 130, 255, cv.THRESH_BINARY)
    thresholded_blue_component, thresholded_green_component, thresholded_red_component = cv.split(thresholded_bgr_image)

    plt.axis("off")
    plt.imshow(np.hstack([thresholded_blue_component, thresholded_green_component, thresholded_red_component]));
    return thresholded_red_component

# %% [markdown]
# # Teste 1

# %%
input_image = cv.imread(target)
input_imagergb = cv.cvtColor(input_image, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(input_imagergb);

# %%
red_comp = kmeans_algorithm(input_image)

# %%
mask_kmeans = red_comp
mask_kmeans_filtered = cv.medianBlur(mask_kmeans, 5)
plt.axis("off")
plt.imshow(np.hstack([mask_kmeans, mask_kmeans_filtered]));

# %% [markdown]
# # Fundo removido

# %%
result_image = cv.bitwise_and(input_image, input_image, mask = mask_kmeans_filtered)
plt.axis("off")
plt.imshow(result_image);

# %%
result_image_gray = cv.cvtColor(result_image, cv.COLOR_BGR2GRAY)

clahe = cv.createCLAHE(clipLimit=30.0, tileGridSize=(6, 8))
equalized2 = clahe.apply(result_image_gray)
plt.axis("off")
plt.imshow(equalized2, cmap = 'gray');

# %%
mask = cv.cvtColor(result_image, cv.COLOR_BGR2RGB)
equalized2 = cv.cvtColor(equalized2, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(np.hstack([mask, equalized2]));

# %% [markdown]
# # Teste 2

# %%
input_image = cv.imread(target2)
input_imagergb = cv.cvtColor(input_image, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(input_imagergb);

# %%
red_comp = kmeans_algorithm(input_image)

# %%
mask_kmeans = red_comp
mask_kmeans_filtered = cv.medianBlur(mask_kmeans, 5)
result_image = cv.bitwise_and(input_image, input_image, mask = mask_kmeans_filtered)
plt.axis("off")
plt.imshow(result_image);

# %%
result_image_gray = cv.cvtColor(result_image, cv.COLOR_BGR2GRAY)

clahe = cv.createCLAHE(clipLimit=30.0, tileGridSize=(6, 8))
equalized2 = clahe.apply(result_image_gray)
plt.axis("off")
plt.imshow(equalized2, cmap = 'gray');

# %%
mask = cv.cvtColor(result_image, cv.COLOR_BGR2RGB)
equalized2 = cv.cvtColor(equalized2, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(np.hstack([mask, equalized2]));

# %% [markdown]
# # Teste 3

# %%
input_image = cv.imread(target3)
input_imagergb = cv.cvtColor(input_image, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(input_imagergb);

# %%
red_comp = kmeans_algorithm(input_image)

# %%
mask_kmeans = red_comp
mask_kmeans_filtered = cv.medianBlur(mask_kmeans, 5)
result_image = cv.bitwise_and(input_image, input_image, mask = mask_kmeans_filtered)
plt.axis("off")
plt.imshow(result_image);

# %%
result_image_gray = cv.cvtColor(result_image, cv.COLOR_BGR2GRAY)

clahe = cv.createCLAHE(clipLimit=30.0, tileGridSize=(6, 8))
equalized2 = clahe.apply(result_image_gray)
plt.axis("off")
plt.imshow(equalized2, cmap = 'gray');

# %%
mask = cv.cvtColor(result_image, cv.COLOR_BGR2RGB)
equalized2 = cv.cvtColor(equalized2, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(np.hstack([mask, equalized2]));

# %% [markdown]
# # Teste 4

# %%
input_image = cv.imread(target4)
input_imagergb = cv.cvtColor(input_image, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(input_imagergb);

# %%
red_comp = kmeans_algorithm(input_image)

# %%
mask_kmeans = red_comp
mask_kmeans_filtered = cv.medianBlur(mask_kmeans, 5)
result_image = cv.bitwise_and(input_image, input_image, mask = mask_kmeans_filtered)
plt.axis("off")
plt.imshow(result_image);

# %%
result_image_gray = cv.cvtColor(result_image, cv.COLOR_BGR2GRAY)

clahe = cv.createCLAHE(clipLimit=30.0, tileGridSize=(6, 8))
equalized2 = clahe.apply(result_image_gray)
plt.axis("off")
plt.imshow(equalized2, cmap = 'gray');

# %%
mask = cv.cvtColor(result_image, cv.COLOR_BGR2RGB)
equalized2 = cv.cvtColor(equalized2, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(np.hstack([mask, equalized2]));

# %% [markdown]
# # Teste 5

# %%
input_image = cv.imread(target5)
input_imagergb = cv.cvtColor(input_image, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(input_imagergb);

# %%
red_comp = kmeans_algorithm(input_image)

# %%
mask_kmeans = red_comp
mask_kmeans_filtered = cv.medianBlur(mask_kmeans, 5)
result_image = cv.bitwise_and(input_image, input_image, mask = mask_kmeans_filtered)
plt.axis("off")
plt.imshow(result_image);

# %%
result_image_gray = cv.cvtColor(result_image, cv.COLOR_BGR2GRAY)

clahe = cv.createCLAHE(clipLimit=30.0, tileGridSize=(6, 8))
equalized2 = clahe.apply(result_image_gray)
plt.axis("off")
plt.imshow(equalized2, cmap = 'gray');

# %%
mask = cv.cvtColor(result_image, cv.COLOR_BGR2RGB)
equalized2 = cv.cvtColor(equalized2, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(np.hstack([mask, equalized2]));

# %% [markdown]
# # Teste 6

# %%
input_image = cv.imread(target6)
input_imagergb = cv.cvtColor(input_image, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(input_imagergb);

# %%
red_comp = kmeans_algorithm(input_image)

# %%
mask_kmeans = red_comp
mask_kmeans_filtered = cv.medianBlur(mask_kmeans, 5)
result_image = cv.bitwise_and(input_image, input_image, mask = mask_kmeans_filtered)
plt.axis("off")
plt.imshow(result_image);

# %%
result_image_gray = cv.cvtColor(result_image, cv.COLOR_BGR2GRAY)

clahe = cv.createCLAHE(clipLimit=30.0, tileGridSize=(6, 8))
equalized2 = clahe.apply(result_image_gray)
plt.axis("off")
plt.imshow(equalized2, cmap = 'gray');

# %%
mask = cv.cvtColor(result_image, cv.COLOR_BGR2RGB)
equalized2 = cv.cvtColor(equalized2, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(np.hstack([mask, equalized2]));

# %% [markdown]
# # Teste 7

# %%
input_image = cv.imread(target7)
input_imagergb = cv.cvtColor(input_image, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(input_imagergb);

# %%
red_comp = kmeans_algorithm(input_image)

# %%
mask_kmeans = red_comp
mask_kmeans_filtered = cv.medianBlur(mask_kmeans, 5)
result_image = cv.bitwise_and(input_image, input_image, mask = mask_kmeans_filtered)
plt.axis("off")
plt.imshow(result_image);

# %%
result_image_gray = cv.cvtColor(result_image, cv.COLOR_BGR2GRAY)

clahe = cv.createCLAHE(clipLimit=30.0, tileGridSize=(6, 8))
equalized2 = clahe.apply(result_image_gray)
plt.axis("off")
plt.imshow(equalized2, cmap = 'gray');

# %%
mask = cv.cvtColor(result_image, cv.COLOR_BGR2RGB)
equalized2 = cv.cvtColor(equalized2, cv.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(np.hstack([mask, equalized2]));
