# %% [markdown]
# # Detecção de Borda

# %% [markdown]
# ### Problema: detectar borda do feijão para cálculo de área total

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
feijao = cv2.cvtColor(feijao, cv2.COLOR_BGR2RGB)
plt.imshow(feijao)
plt.show()

# %% [markdown]
# ### Estratégia 1: removendo o fundo azul

# %%
hsv = cv2.cvtColor(feijao, cv2.COLOR_BGR2HSV)

lower = np.array([94, 80, 2])
upper = np.array([126, 255, 255])

mask = cv2.inRange(hsv, lower, upper)
plt.imshow(mask)
plt.show()

# %%
feijao = cv2.cvtColor(feijao, cv2.COLOR_BGR2RGB)

result = cv2.bitwise_and(feijao ,feijao, mask = mask)
plt.imshow(np.hstack([feijao, result]))

# %% [markdown]
# ### Estratégia 2: usando filtro Canny

# %%
feijao = cv2.cvtColor(feijao, cv2.COLOR_BGR2RGB)
canny = cv2.Canny(feijao, 180, 180)
plt.imshow(canny)
plt.show()
